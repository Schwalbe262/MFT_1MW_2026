# %%
import matplotlib.pyplot as plt

# B fill factor 고려 / volume fill factor 고려 X

B = [
    0.112793082,
    0.225586163,
    0.338379245,
    0.451172326,
    0.563965408,
    0.676758489,
    0.789551571,
    0.902344652,
]

coreloss_measured = [
    1.25,
    5.53,
    10.125,
    14.89,
    19.26,
    23.7,
    28.3,
    37.72,
]

core_loss_volume = [
    1.028739589,
    3.436352013,
    6.958192451,
    11.47862421,
    16.92439921,
    23.24280983,
    30.39317305,
    38.34264164,
]

core_loss_weight = [
    1.020024183,
    3.407239491,
    6.899243157,
    11.38137815,
    16.78101694,
    23.04589845,
    30.13568432,
    38.0178056,
]

# Plotting
plt.figure(figsize=(7, 5))  # 오른쪽으로 길게

plt.plot(B, coreloss_measured, label="coreloss_measured", marker='o', linestyle='-')
plt.plot(B, core_loss_volume, label="core_loss (volume_based)", marker='s', linestyle='--')
plt.plot(B, core_loss_weight, label="core_loss (weight_based)", marker='^', linestyle='--')
plt.xlabel("B (T)")
plt.ylabel("Core Loss Value")
plt.title("Core Loss Comparison (B vs Loss)")
plt.legend()
plt.grid(True)
plt.show()
