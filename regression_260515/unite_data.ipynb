# %%
import pandas as pd

# CSV 파일 불러오기
df1 = pd.read_csv("simulation_results1.csv")
df2 = pd.read_csv("simulation_results2.csv")
df3 = pd.read_csv("simulation_results3.csv")
df4 = pd.read_csv("simulation_results4.csv")
df5 = pd.read_csv("simulation_results5.csv")

# 두 데이터프레임 합치기
df_combined = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# 합친 데이터프레임 저장
df_combined.to_csv("simulation_results.csv", index=False)

df_combined
# Out:
#        N1  N2  N1_main  N1_side  N2_main  N2_side   w1  l1     l2   h1  ...  \
# 0       5  50        4        1       42        8  452  49  385.5  628  ...
# 1       6  60        4        2       35       25  373  83  364.5  649  ...
# 2       5  50        3        2       44        6  709  97  332.5  383  ...
# 3       5  50        3        2       30       20  348  48  327.5  475  ...
# 4       5  50        3        2       23       27  383  72  278.0  647  ...
# ...    ..  ..      ...      ...      ...      ...  ...  ..    ...  ...  ...
# 26914   6  60        4        2       59        1  712  53  364.0  786  ...
# 26915   9  90        9        0       67       23  709  70  353.0  499  ...
# 26916   6  60        5        1       52        8  748  76  290.5  366  ...
# 26917   5  50        5        0       34       16  469  83  267.0  356  ...
# 26918   6  60        3        3       38       22  596  47  352.0  633  ...
#
# ...

# %%
df = df_combined.sort_values(by="time", ascending=False)
df
# Out:
#       N1   N2  N1_main  N1_side  N2_main  N2_side   w1  l1     l2   h1  \
# 5360   9   90        8        1       86        4  744  42  502.0  848
# 8718  10  100       10        0       45       55  393  64  452.0  622
# 5704  10  100        7        3       22       78  734  61  438.5  747
# 5845   9   90        8        1       21       69  735  99  328.5  748
# 8082   5   50        4        1       18       32  724  89  403.0  559
# ...   ..  ...      ...      ...      ...      ...  ...  ..    ...  ...
# 2760   5   50        4        1       36       14  233  84  299.0  354
# 3028   5   50        5        0       46        4  357  62  318.5  572
# 4724   5   50        4        1       50        0  381  91  280.5  362
# 1031   5   50        3        2       32       18  227  72  270.5  399
# 1492   5   50        5        0       50        0  284  41  340.5  528
#
#       cc_w2c_space_x  w2c_w1c_space_x  w1c_w2s_space_x  w2s_w1s_space_x  \
# ...

# %%
df_combined["time"].mean()
# Out:
# np.float64(2280.681770431087)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_csv("simulation_results.csv")

df = df[(df["Llt"] >= 26) & (df["Llt"] <= 28)]
df = df[(df["P_Tx_main_winding_inner"] < 250) & (df["P_Tx_main_winding_inner"] != 0)]
df = df[(df["P_Tx_main_winding_outer"] < 250) & (df["P_Tx_main_winding_outer"] != 0)]

# Tx_loss + Rx_loss 내림차순으로 정렬
# df_sorted = df.sort_values(by=(df["Tx_loss"] + df["Rx_loss"]), ascending=False)
# df_sorted
df
# Out:
#       N1   N2  N1_main  N1_side  N2_main  N2_side   w1   l1     l2   h1  \
# 236    7   70        7        0       28       42  496   72  274.0  591
# 635    8   80        6        2       28       52  608   85  425.0  518
# 1164   9   90        7        2       34       56  632   96  356.5  796
# 1770  10  100        6        4       21       79  536   45  410.5  834
# 1840  10  100        7        3       25       75  249   52  465.0  892
# 2514  10  100        8        2       44       56  614   70  308.5  512
# 2651   8   80        6        2       22       58  300   85  403.5  415
# 3614  10  100        7        3       26       74  241   94  391.5  647
# 4319   8   80        7        1       33       47  672   76  255.5  518
# 4930   9   90        5        4       81        9  490   83  331.0  657
# 5216   8   80        7        1       32       48  531   84  353.0  559
# 5297   8   80        7        1       24       56  353   67  357.0  749
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df_combined["time"], bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Tx_loss")
plt.xlabel("Tx_loss")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df_combined["Tx_loss"] + df_combined["Rx_loss"], bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Tx_loss")
plt.xlabel("Tx_loss")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
x = df_combined["Tx_loss"] + df_combined["Rx_loss"]
y = df_combined["Llt"]
plt.scatter(x, y, c='skyblue', edgecolor='black', alpha=0.7)
plt.title("Tx_loss + Rx_loss vs Llt")
plt.xlabel("Tx_loss + Rx_loss")
plt.ylabel("Llt")
plt.grid(True, alpha=0.75)
plt.show()
